# %% [markdown]
# <a href="https://colab.research.google.com/github/RaviKumarKachhi/Alexa_project/blob/main/CyFuture_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers transformers accelerate torch

# %%
from diffusers import StableDiffusionPipeline
import torch

# Set the device
device = "cuda" if torch.cuda.is_available() else "cpu"

# Load Stable Diffusion Pipeline
pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",  # You can also try stabilityai/stable-diffusion-2-1
    torch_dtype=torch.float16 if device == "cuda" else torch.float32
)
pipe = pipe.to(device)

# Prompt input
prompt = "please make cow images"

# Generate image
image = pipe(prompt=prompt, guidance_scale=7.5).images[0]

# Save output
image.save("generated_image.png")

print("Image saved as generated_image.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# Image saved as generated_image.png
